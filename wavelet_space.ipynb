# %% [markdown]
# # Wavelet Module testing/debugging

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import skimage
from skimage import data
import pytorch_wavelet as wavelet

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

dtype = torch.complex64
ctype = torch.float32
device = 'cpu'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Image

# %%
x = data.camera()
x = torch.from_numpy(x)

# %% [markdown]
# ## Wavelet Transform testing

# %%
a1 = wavelet.visualize(x, Nlayers=1)
a2 = wavelet.visualize(x, Nlayers=2)

plt.figure()
plt.subplot(131)
plt.imshow(x)
plt.axis('off')
plt.title('Image')
plt.subplot(132)
plt.imshow(a1)
plt.axis('off')
plt.title('Wavelet Level 1')
plt.subplot(133)
plt.imshow(a2)
plt.axis('off')
plt.title('Wavelet Level 2')

plt.savefig('figures/output.pdf', dpi=300, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
